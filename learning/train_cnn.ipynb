# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
from sklearn.metrics import classification_report
from models import CNNClassifier
import warnings
warnings.filterwarnings('ignore')

# %%
nconf = 30
t_sum = 2.1
prm_list = []
for i in range(nconf + 1):
    prm_list.append([t_sum, f"dataset/2d_Ising/L64/L64T{i}_"])
    t_sum += 0.01
print(prm_list)
# Temterature30 x conf50 = 3000 data
# Out:
# [[2.1, 'dataset/2d_Ising/L64/L64T0_'], [2.11, 'dataset/2d_Ising/L64/L64T1_'], [2.1199999999999997, 'dataset/2d_Ising/L64/L64T2_'], [2.1299999999999994, 'dataset/2d_Ising/L64/L64T3_'], [2.1399999999999992, 'dataset/2d_Ising/L64/L64T4_'], [2.149999999999999, 'dataset/2d_Ising/L64/L64T5_'], [2.159999999999999, 'dataset/2d_Ising/L64/L64T6_'], [2.1699999999999986, 'dataset/2d_Ising/L64/L64T7_'], [2.1799999999999984, 'dataset/2d_Ising/L64/L64T8_'], [2.189999999999998, 'dataset/2d_Ising/L64/L64T9_'], [2.199999999999998, 'dataset/2d_Ising/L64/L64T10_'], [2.2099999999999977, 'dataset/2d_Ising/L64/L64T11_'], [2.2199999999999975, 'dataset/2d_Ising/L64/L64T12_'], [2.2299999999999973, 'dataset/2d_Ising/L64/L64T13_'], [2.239999999999997, 'dataset/2d_Ising/L64/L64T14_'], [2.249999999999997, 'dataset/2d_Ising/L64/L64T15_'], [2.2599999999999967, 'dataset/2d_Ising/L64/L64T16_'], [2.2699999999999965, 'dataset/2d_Ising/L64/L64T17_'], [2.2799999999999963, 'dataset/2d_Ising/L64/L64T18_'], [2.289999999999996, 'dataset/2d_Ising/L64/L64T19_'], [2.299999999999996, 'dataset/2d_Ising/L64/L64T20_'], [2.3099999999999956, 'dataset/2d_Ising/L64/L64T21_'], [2.3199999999999954, 'dataset/2d_Ising/L64/L64T22_'], [2.329999999999995, 'dataset/2d_Ising/L64/L64T23_'], [2.339999999999995, 'dataset/2d_Ising/L64/L64T24_'], [2.3499999999999948, 'dataset/2d_Ising/L64/L64T25_'], [2.3599999999999945, 'dataset/2d_Ising/L64/L64T26_'], [2.3699999999999943, 'dataset/2d_Ising/L64/L64T27_'], [2.379999999999994, 'dataset/2d_Ising/L64/L64T28_'], [2.389999999999994, 'dataset/2d_Ising/L64/L64T29_'], [2.3999999999999937, 'dataset/2d_Ising/L64/L64T30_']]

# %%
for num in ["11", "13", "15", "17", "19", "21", "23"]:
    for iconf in range(1):
        file = f"dataset/2d_Ising/L64/L64T{num}_{iconf}.npy"
        print(num)
        sc = np.load(file)
        plt.imshow(sc, interpolation='nearest', vmin=0, vmax=1, cmap='jet')
        plt.show()
# Out:
# 11
# 13
# 15
# 17
# 19
# 21
# 23

# %%
ndata = 50
T_cr = 2.269 # critical temp for 2d ising

data = []
labels = []
temps = []
nprm = len(prm_list)
for itemp in range(nprm):
    temp = prm_list[itemp][0]
    fname = prm_list[itemp][1]
    for itrj in range(ndata):
        npsc = np.load(f"{fname}{itrj}.npy")
        data.append(npsc)
        if temp > T_cr:
            labels.append(1)
        else:
            labels.append(0)
        temps.append(temp)
data = torch.tensor(data, dtype=torch.float32).unsqueeze(1)
labels = torch.tensor(labels, dtype=torch.float32)
train_data = data[0::2]
train_labels = labels[0::2]
train_temps = temps[0::2]
val_data = data[1::2]
val_labels = labels[1::2]
val_temps = temps[1::2]

# %%
print("train_data.shape = ", train_data.shape)
print("train_labels.shape = ", train_labels.shape)
print("val_data.shape = ", val_data.shape)
# Out:
# train_data.shape =  torch.Size([775, 1, 64, 64])
# train_labels.shape =  torch.Size([775])
# val_data.shape =  torch.Size([775, 1, 64, 64])

# %%
train_loader = DataLoader(TensorDataset(train_data, train_labels), batch_size=10, shuffle=True)
valid_loader = DataLoader(TensorDataset(val_data, val_labels), batch_size=10, shuffle=False)

# %%
model = CNNClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
epochs = 5
losses = []
accuracy_list = []
for epoch in range(epochs):
    model.train()
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target.type(torch.long))
        loss.backward()
        del loss
        optimizer.step()
    
    model.eval()
    valid_loss = 0
    correct = 0
    answer = []
    prediction = []
    with torch.no_grad():
        for data, target in valid_loader:
            output = model(data)
            valid_loss += criterion(output, target.type(torch.long)).item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            prediction += list(pred.cpu().numpy())
            answer += list(target.cpu().numpy())

    valid_loss /= len(valid_loader.dataset)
    accuracy = 100 * correct / len(valid_loader.dataset)
    losses.append(valid_loss)
    accuracy_list.append(accuracy)
    print(f'Epoch: {epoch+1}, Validation loss: {valid_loss}, Accuracy: {accuracy}%')
    print("Classification Report:\n", classification_report(
        answer, prediction, digits=4))
print("done.")
torch.save(model, "2d_Ising_model_classifier.pth")
# Out:
# Epoch: 1, Validation loss: 0.00837922264503408, Accuracy: 96.25806451612904%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.9361    1.0000    0.9670       425
#          1.0     1.0000    0.9171    0.9568       350
#
#     accuracy                         0.9626       775
#    macro avg     0.9681    0.9586    0.9619       775
# weighted avg     0.9650    0.9626    0.9624       775
#
# Epoch: 2, Validation loss: 0.0018766016353476752, Accuracy: 99.61290322580645%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.9930    1.0000    0.9965       425
#          1.0     1.0000    0.9914    0.9957       350
#
#     accuracy                         0.9961       775
#    macro avg     0.9965    0.9957    0.9961       775
# weighted avg     0.9962    0.9961    0.9961       775
#
# Epoch: 3, Validation loss: 0.00010706940435085244, Accuracy: 100.0%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000       425
#          1.0     1.0000    1.0000    1.0000       350
#
#     accuracy                         1.0000       775
#    macro avg     1.0000    1.0000    1.0000       775
# weighted avg     1.0000    1.0000    1.0000       775
#
# Epoch: 4, Validation loss: 0.007456333116817726, Accuracy: 98.19354838709677%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.9835    0.9835    0.9835       425
#          1.0     0.9800    0.9800    0.9800       350
#
#     accuracy                         0.9819       775
#    macro avg     0.9818    0.9818    0.9818       775
# weighted avg     0.9819    0.9819    0.9819       775
#
# Epoch: 5, Validation loss: 0.0003309140485709261, Accuracy: 100.0%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000       425
#          1.0     1.0000    1.0000    1.0000       350
#
#     accuracy                         1.0000       775
#    macro avg     1.0000    1.0000    1.0000       775
# weighted avg     1.0000    1.0000    1.0000       775
#
# done.

# %%
plt.xlabel('epochs')
plt.ylabel('loss function')
plt.plot(np.arange(1, epochs+1), losses)
plt.show()
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(1, epochs+1), accuracy_list)
plt.show()

# %%
xs = []
y1s = []
y2s = []
Ndatamax = 775
Nsameclass = 25
for j in range(0, Ndatamax, Nsameclass):
    result = model(val_data[j:j+Nsameclass])
    x = val_temps[j]
    y1 = np.mean(result.argmax(dim=1, keepdim=True).detach().numpy().copy())
    y2 = 1 - np.mean(result.argmax(dim=1, keepdim=True).detach().numpy().copy())
    xs.append(x)
    y1s.append(y1)
    y2s.append(y2)
    # print(x, y1, y2)
plt.axvline(x=2.269, ymin=0, ymax=1, ls="dashed", color="gray", label=r"$T_c=2.269$")
plt.xlim(2.1,2.4)
plt.plot(xs, y1s, label=r"$T>T_c$", marker="o", color="red")
plt.plot(xs, y2s, label=r"$T<T_c$", marker="o", color="blue")
plt.legend()
plt.xlabel(r"$T$")
plt.ylabel(r"Prob")
plt.show()

# %%
nconf = 30
t_sum = 0.85
prm_list = []
for i in range(nconf + 1):
    prm_list.append([t_sum, f"dataset/2d_Potts/L64/L64T{i}_"])
    t_sum += 0.01
print(prm_list)
# Temterature30 x conf50 = 3000 data
# Out:
# [[0.85, 'dataset/2d_Potts/L64/L64T0_'], [0.86, 'dataset/2d_Potts/L64/L64T1_'], [0.87, 'dataset/2d_Potts/L64/L64T2_'], [0.88, 'dataset/2d_Potts/L64/L64T3_'], [0.89, 'dataset/2d_Potts/L64/L64T4_'], [0.9, 'dataset/2d_Potts/L64/L64T5_'], [0.91, 'dataset/2d_Potts/L64/L64T6_'], [0.92, 'dataset/2d_Potts/L64/L64T7_'], [0.93, 'dataset/2d_Potts/L64/L64T8_'], [0.9400000000000001, 'dataset/2d_Potts/L64/L64T9_'], [0.9500000000000001, 'dataset/2d_Potts/L64/L64T10_'], [0.9600000000000001, 'dataset/2d_Potts/L64/L64T11_'], [0.9700000000000001, 'dataset/2d_Potts/L64/L64T12_'], [0.9800000000000001, 'dataset/2d_Potts/L64/L64T13_'], [0.9900000000000001, 'dataset/2d_Potts/L64/L64T14_'], [1.0, 'dataset/2d_Potts/L64/L64T15_'], [1.01, 'dataset/2d_Potts/L64/L64T16_'], [1.02, 'dataset/2d_Potts/L64/L64T17_'], [1.03, 'dataset/2d_Potts/L64/L64T18_'], [1.04, 'dataset/2d_Potts/L64/L64T19_'], [1.05, 'dataset/2d_Potts/L64/L64T20_'], [1.06, 'dataset/2d_Potts/L64/L64T21_'], [1.07, 'dataset/2d_Potts/L64/L64T22_'], [1.08, 'dataset/2d_Potts/L64/L64T23_'], [1.09, 'dataset/2d_Potts/L64/L64T24_'], [1.1, 'dataset/2d_Potts/L64/L64T25_'], [1.11, 'dataset/2d_Potts/L64/L64T26_'], [1.12, 'dataset/2d_Potts/L64/L64T27_'], [1.1300000000000001, 'dataset/2d_Potts/L64/L64T28_'], [1.1400000000000001, 'dataset/2d_Potts/L64/L64T29_'], [1.1500000000000001, 'dataset/2d_Potts/L64/L64T30_']]

# %%
for num in ["12", "13", "14", "15", "16", "17"]:
    for iconf in range(1):
        file = f"dataset/2d_Potts/L64/L64T{num}_{iconf}.npy"
        print(num)
        sc = np.load(file)
        plt.imshow(sc, interpolation='nearest', vmin=0, vmax=2, cmap='jet')
        plt.show()
# Out:
# 12
# 13
# 14
# 15
# 16
# 17

# %%
ndata = 25
T_cr = 1/np.log(1+np.sqrt(3)) # critical temp for 2d 3-Potts

data = []
labels = []
temps = []
nprm = len(prm_list)
for itemp in range(nprm):
    temp = prm_list[itemp][0]
    fname = prm_list[itemp][1]
    for itrj in range(ndata):
        npsc = np.load(f"{fname}{itrj}.npy")
        data.append(npsc)
        if temp > T_cr:
            labels.append(1)
        else:
            labels.append(0)
        temps.append(temp)
data = torch.tensor(data, dtype=torch.float32).unsqueeze(1)
labels = torch.tensor(labels, dtype=torch.float32)
train_data = data[0::2]
train_labels = labels[0::2]
train_temps = temps[0::2]
val_data = data[1::2]
val_labels = labels[1::2]
val_temps = temps[1::2]

# %%
print("train_data.shape = ", train_data.shape)
print("train_labels.shape = ", train_labels.shape)
print("val_data.shape = ", val_data.shape)
# Out:
# train_data.shape =  torch.Size([388, 1, 64, 64])
# train_labels.shape =  torch.Size([388])
# val_data.shape =  torch.Size([387, 1, 64, 64])

# %%
train_loader = DataLoader(TensorDataset(train_data, train_labels), batch_size=10, shuffle=True)
valid_loader = DataLoader(TensorDataset(val_data, val_labels), batch_size=10, shuffle=False)

# %%
model = CNNClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
epochs = 5
losses = []
accuracy_list = []
for epoch in range(epochs):
    model.train()
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target.type(torch.long))
        loss.backward()
        del loss
        optimizer.step()
    
    model.eval()
    valid_loss = 0
    correct = 0
    answer = []
    prediction = []
    with torch.no_grad():
        for data, target in valid_loader:
            output = model(data)
            valid_loss += criterion(output, target.type(torch.long)).item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            prediction += list(pred.cpu().numpy())
            answer += list(target.cpu().numpy())

    valid_loss /= len(valid_loader.dataset)
    accuracy = 100 * correct / len(valid_loader.dataset)
    losses.append(valid_loss)
    accuracy_list.append(accuracy)
    print(f'Epoch: {epoch+1}, Validation loss: {valid_loss}, Accuracy: {accuracy}%')
    print("Classification Report:\n", classification_report(
        answer, prediction, digits=4))
print("done.")
torch.save(model, "2d_Potts_model_classifier.pth")
# Out:
# Epoch: 1, Validation loss: 1.9931590407453066e-05, Accuracy: 100.0%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000       187
#          1.0     1.0000    1.0000    1.0000       200
#
#     accuracy                         1.0000       387
#    macro avg     1.0000    1.0000    1.0000       387
# weighted avg     1.0000    1.0000    1.0000       387
#
# Epoch: 2, Validation loss: 1.5534666847548263e-06, Accuracy: 100.0%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000       187
#          1.0     1.0000    1.0000    1.0000       200
#
#     accuracy                         1.0000       387
#    macro avg     1.0000    1.0000    1.0000       387
# weighted avg     1.0000    1.0000    1.0000       387
#
# Epoch: 3, Validation loss: 1.4301162765232326e-06, Accuracy: 100.0%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000       187
#          1.0     1.0000    1.0000    1.0000       200
#
#     accuracy                         1.0000       387
#    macro avg     1.0000    1.0000    1.0000       387
# weighted avg     1.0000    1.0000    1.0000       387
#
# Epoch: 4, Validation loss: 1.235231095671114e-06, Accuracy: 100.0%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000       187
#          1.0     1.0000    1.0000    1.0000       200
#
#     accuracy                         1.0000       387
#    macro avg     1.0000    1.0000    1.0000       387
# weighted avg     1.0000    1.0000    1.0000       387
#
# Epoch: 5, Validation loss: 8.747535115531578e-07, Accuracy: 100.0%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     1.0000    1.0000    1.0000       187
#          1.0     1.0000    1.0000    1.0000       200
#
#     accuracy                         1.0000       387
#    macro avg     1.0000    1.0000    1.0000       387
# weighted avg     1.0000    1.0000    1.0000       387
#
# done.

# %%
plt.xlabel('epochs')
plt.ylabel('loss function')
plt.plot(np.arange(1, epochs+1), losses)
plt.show()
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(1, epochs+1), accuracy_list)
plt.show()

# %%
xs = []
y1s = []
y2s = []
Ndatamax = 387
Nsameclass = 25
for j in range(0, Ndatamax, Nsameclass):
    result = model(val_data[j:j+Nsameclass])
    x = val_temps[j]
    y1 = np.mean(result.argmax(dim=1, keepdim=True).detach().numpy().copy())
    y2 = 1 - np.mean(result.argmax(dim=1, keepdim=True).detach().numpy().copy())
    xs.append(x)
    y1s.append(y1)
    y2s.append(y2)
    # print(x, y1, y2)
plt.axvline(x=0.995, ymin=0, ymax=1, ls="dashed", color="gray", label=r"$T_c=0.995$")
plt.xlim(0.85,1.15)
plt.plot(xs, y1s, label=r"$T>T_c$", marker="o", color="red")
plt.plot(xs, y2s, label=r"$T<T_c$", marker="o", color="blue")
plt.legend()
plt.xlabel(r"$T$")
plt.ylabel(r"Prob")
plt.show()

# %%
nconf = 50
t_sum = 0.9
prm_list = []
for i in range(nconf + 1):
    prm_list.append([t_sum, f"dataset/2d_Clock/L64_q=4/L64T{i}_"])
    t_sum += 0.01
print(prm_list)
# Temterature30 x conf50 = 3000 data
# Out:
# [[0.9, 'dataset/2d_Clock/L64_q=4/L64T0_'], [0.91, 'dataset/2d_Clock/L64_q=4/L64T1_'], [0.92, 'dataset/2d_Clock/L64_q=4/L64T2_'], [0.93, 'dataset/2d_Clock/L64_q=4/L64T3_'], [0.9400000000000001, 'dataset/2d_Clock/L64_q=4/L64T4_'], [0.9500000000000001, 'dataset/2d_Clock/L64_q=4/L64T5_'], [0.9600000000000001, 'dataset/2d_Clock/L64_q=4/L64T6_'], [0.9700000000000001, 'dataset/2d_Clock/L64_q=4/L64T7_'], [0.9800000000000001, 'dataset/2d_Clock/L64_q=4/L64T8_'], [0.9900000000000001, 'dataset/2d_Clock/L64_q=4/L64T9_'], [1.0, 'dataset/2d_Clock/L64_q=4/L64T10_'], [1.01, 'dataset/2d_Clock/L64_q=4/L64T11_'], [1.02, 'dataset/2d_Clock/L64_q=4/L64T12_'], [1.03, 'dataset/2d_Clock/L64_q=4/L64T13_'], [1.04, 'dataset/2d_Clock/L64_q=4/L64T14_'], [1.05, 'dataset/2d_Clock/L64_q=4/L64T15_'], [1.06, 'dataset/2d_Clock/L64_q=4/L64T16_'], [1.07, 'dataset/2d_Clock/L64_q=4/L64T17_'], [1.08, 'dataset/2d_Clock/L64_q=4/L64T18_'], [1.09, 'dataset/2d_Clock/L64_q=4/L64T19_'], [1.1, 'dataset/2d_Clock/L64_q=4/L64T20_'], [1.11, 'dataset/2d_Clock/L64_q=4/L64T21_'], [1.12, 'dataset/2d_Clock/L64_q=4/L64T22_'], [1.1300000000000001, 'dataset/2d_Clock/L64_q=4/L64T23_'], [1.1400000000000001, 'dataset/2d_Clock/L64_q=4/L64T24_'], [1.1500000000000001, 'dataset/2d_Clock/L64_q=4/L64T25_'], [1.1600000000000001, 'dataset/2d_Clock/L64_q=4/L64T26_'], [1.1700000000000002, 'dataset/2d_Clock/L64_q=4/L64T27_'], [1.1800000000000002, 'dataset/2d_Clock/L64_q=4/L64T28_'], [1.1900000000000002, 'dataset/2d_Clock/L64_q=4/L64T29_'], [1.2000000000000002, 'dataset/2d_Clock/L64_q=4/L64T30_'], [1.2100000000000002, 'dataset/2d_Clock/L64_q=4/L64T31_'], [1.2200000000000002, 'dataset/2d_Clock/L64_q=4/L64T32_'], [1.2300000000000002, 'dataset/2d_Clock/L64_q=4/L64T33_'], [1.2400000000000002, 'dataset/2d_Clock/L64_q=4/L64T34_'], [1.2500000000000002, 'dataset/2d_Clock/L64_q=4/L64T35_'], [1.2600000000000002, 'dataset/2d_Clock/L64_q=4/L64T36_'], [1.2700000000000002, 'dataset/2d_Clock/L64_q=4/L64T37_'], [1.2800000000000002, 'dataset/2d_Clock/L64_q=4/L64T38_'], [1.2900000000000003, 'dataset/2d_Clock/L64_q=4/L64T39_'], [1.3000000000000003, 'dataset/2d_Clock/L64_q=4/L64T40_'], [1.3100000000000003, 'dataset/2d_Clock/L64_q=4/L64T41_'], [1.3200000000000003, 'dataset/2d_Clock/L64_q=4/L64T42_'], [1.3300000000000003, 'dataset/2d_Clock/L64_q=4/L64T43_'], [1.3400000000000003, 'dataset/2d_Clock/L64_q=4/L64T44_'], [1.3500000000000003, 'dataset/2d_Clock/L64_q=4/L64T45_'], [1.3600000000000003, 'dataset/2d_Clock/L64_q=4/L64T46_'], [1.3700000000000003, 'dataset/2d_Clock/L64_q=4/L64T47_'], [1.3800000000000003, 'dataset/2d_Clock/L64_q=4/L64T48_'], [1.3900000000000003, 'dataset/2d_Clock/L64_q=4/L64T49_'], [1.4000000000000004, 'dataset/2d_Clock/L64_q=4/L64T50_']]

# %%
for num in ["17", "19", "21", "23", "25"]:
    for iconf in range(1):
        file = f"dataset/2d_Clock/L64_q=4/L64T{num}_{iconf}.npy"
        print(num)
        sc = np.load(file)
        plt.imshow(sc, interpolation='nearest', vmin=0, vmax=3, cmap='jet')
        plt.show()
# Out:
# 17
# 19
# 21
# 23
# 25

# %%
ndata = 25
T_cr = 1/np.log(1+np.sqrt(2)) # critical temp for 2d 4-Clock

data = []
labels = []
temps = []
nprm = len(prm_list)
for itemp in range(nprm):
    temp = prm_list[itemp][0]
    fname = prm_list[itemp][1]
    for itrj in range(ndata):
        npsc = np.load(f"{fname}{itrj}.npy")
        data.append(npsc)
        if temp > T_cr:
            labels.append(1)
        else:
            labels.append(0)
        temps.append(temp)
data = torch.tensor(data, dtype=torch.float32).unsqueeze(1)
labels = torch.tensor(labels, dtype=torch.float32)
train_data = data[0::2]
train_labels = labels[0::2]
train_temps = temps[0::2]
val_data = data[1::2]
val_labels = labels[1::2]
val_temps = temps[1::2]

# %%
print("train_data.shape = ", train_data.shape)
print("train_labels.shape = ", train_labels.shape)
print("val_data.shape = ", val_data.shape)
# Out:
# train_data.shape =  torch.Size([638, 1, 64, 64])
# train_labels.shape =  torch.Size([638])
# val_data.shape =  torch.Size([637, 1, 64, 64])

# %%
model = CNNClassifier()
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
epochs = 5
losses = []
accuracy_list = []
for epoch in range(epochs):
    model.train()
    for data, target in train_loader:
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target.type(torch.long))
        loss.backward()
        del loss
        optimizer.step()
    
    model.eval()
    valid_loss = 0
    correct = 0
    answer = []
    prediction = []
    with torch.no_grad():
        for data, target in valid_loader:
            output = model(data)
            valid_loss += criterion(output, target.type(torch.long)).item()
            pred = output.argmax(dim=1, keepdim=True)
            correct += pred.eq(target.view_as(pred)).sum().item()
            prediction += list(pred.cpu().numpy())
            answer += list(target.cpu().numpy())

    valid_loss /= len(valid_loader.dataset)
    accuracy = 100 * correct / len(valid_loader.dataset)
    losses.append(valid_loss)
    accuracy_list.append(accuracy)
    print(f'Epoch: {epoch+1}, Validation loss: {valid_loss}, Accuracy: {accuracy}%')
    print("Classification Report:\n", classification_report(
        answer, prediction, digits=4))
print("done.")
torch.save(model, "2d_Clock_model_classifier.pth")
# Out:
# Epoch: 1, Validation loss: 0.06977064757384072, Accuracy: 51.679586563307495%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000       187
#          1.0     0.5168    1.0000    0.6814       200
#
#     accuracy                         0.5168       387
#    macro avg     0.2584    0.5000    0.3407       387
# weighted avg     0.2671    0.5168    0.3522       387
#
# Epoch: 2, Validation loss: 0.06977849074420386, Accuracy: 51.679586563307495%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000       187
#          1.0     0.5168    1.0000    0.6814       200
#
#     accuracy                         0.5168       387
#    macro avg     0.2584    0.5000    0.3407       387
# weighted avg     0.2671    0.5168    0.3522       387
#
# Epoch: 3, Validation loss: 0.06976808873257896, Accuracy: 51.679586563307495%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000       187
#          1.0     0.5168    1.0000    0.6814       200
#
#     accuracy                         0.5168       387
#    macro avg     0.2584    0.5000    0.3407       387
# weighted avg     0.2671    0.5168    0.3522       387
#
# Epoch: 4, Validation loss: 0.06977188602590438, Accuracy: 51.679586563307495%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000       187
#          1.0     0.5168    1.0000    0.6814       200
#
#     accuracy                         0.5168       387
#    macro avg     0.2584    0.5000    0.3407       387
# weighted avg     0.2671    0.5168    0.3522       387
#
# Epoch: 5, Validation loss: 0.06981322839278584, Accuracy: 51.679586563307495%
# Classification Report:
#                precision    recall  f1-score   support
#
#          0.0     0.0000    0.0000    0.0000       187
#          1.0     0.5168    1.0000    0.6814       200
#
#     accuracy                         0.5168       387
#    macro avg     0.2584    0.5000    0.3407       387
# weighted avg     0.2671    0.5168    0.3522       387
#
# done.

# %%
plt.xlabel('epochs')
plt.ylabel('loss function')
plt.plot(np.arange(1, epochs+1), losses)
plt.show()
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.plot(np.arange(1, epochs+1), accuracy_list)
plt.show()

# %%
xs = []
y1s = []
y2s = []
Ndatamax = 637
Nsameclass = 25
for j in range(0, Ndatamax, Nsameclass):
    result = model(val_data[j:j+Nsameclass])
    x = val_temps[j]
    y1 = np.mean(result.argmax(dim=1, keepdim=True).detach().numpy().copy())
    y2 = 1 - np.mean(result.argmax(dim=1, keepdim=True).detach().numpy().copy())
    xs.append(x)
    y1s.append(y1)
    y2s.append(y2)
    # print(x, y1, y2)
plt.axvline(x=1.135, ymin=0, ymax=1, ls="dashed", color="gray", label=r"$T_c=1.135$")
plt.xlim(0.9,1.4)
plt.plot(xs, y1s, label=r"$T>T_c$", marker="o", color="red")
plt.plot(xs, y2s, label=r"$T<T_c$", marker="o", color="blue")
plt.legend()
plt.xlabel(r"$T$")
plt.ylabel(r"Prob")
plt.show()
